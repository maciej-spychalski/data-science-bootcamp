# %% [markdown]
# <a href="https://colab.research.google.com/github/maciej-spychalski/data-science-bootcamp/blob/main/intro.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
text = 62 # @param {"type":"slider","min":0,"max":100,"step":1}
# Out:
# Hello
